# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 5
READ_PATH = "D:\\Main\\MA_PROGR\\Data\\UNET_Output\\Session14"
file_name = "00_overall_train_loss.npy"


train_loss_big = np.load(f"{READ_PATH}\\{file_name}")
# train_loss_big

# %%
train_loss_just_epochs = []
for idx, elem in enumerate(train_loss_big):
    if idx % BATCH_SIZE == 0:
        train_loss_just_epochs.append(elem)

# train_loss_just_epochs

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_loss_just_epochs)
